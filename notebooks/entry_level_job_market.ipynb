# %% [markdown]
# # Entry-Level Data Job Market Analytics
# Complete the checkpoints in order and write down what you learn.

# %% [markdown]
# ## 1. Load and inspect
# TODO: load the raw CSV; inspect shape, columns, data types, missingness, duplicates, and sample rows.

# %%
import pandas as pd

# TODO: load ../data/raw/gsearch_jobs.csv

# %% [markdown]
# ## 2. Define entry level
# Write the rule in plain English before coding it. Audit included and excluded samples.

# %%
# TODO: build and audit your entry-level classifier

# %% [markdown]
# ## 3. Skills and market questions
# TODO: normalize skills, calculate distinct-posting frequencies, and compare groups.

# %%
# TODO: create your analysis tables and visualizations

# %% [markdown]
# ## 4. Conclusions and limitations
# Write 3–5 findings. Support each with a number and discuss one limitation.
